# %%
# Useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import BasicAer, execute
from qiskit.quantum_info import Pauli, state_fidelity, basis_state, process_fidelity 

from qiskit.circuit import Parameter

# %%
n=6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

#circ.draw(output='mpl')

phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
circuits[11].draw(output='mpl')
circuits[1].draw()

job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range6 = phi_range
counts6 = [job.result().get_counts(i) for i in range(len(job.result().results))] 

print(counts6)
print(list(map(lambda c: 1/1024*c.get('0',0), counts6)))
# Out:
# [0.0, 0.4487989505128276, 0.8975979010256552, 1.3463968515384828, 1.7951958020513104, 2.243994752564138, 2.6927937030769655, 3.141592653589793, 3.5903916041026207, 4.039190554615448, 4.487989505128276, 4.936788455641103, 5.385587406153931, 5.8343863566667595]
# [{'0': 1024}, {'1': 972, '0': 52}, {'1': 175, '0': 849}, {'1': 623, '0': 401}, {'1': 622, '0': 402}, {'1': 166, '0': 858}, {'1': 977, '0': 47}, {'0': 1024}, {'1': 972, '0': 52}, {'1': 203, '0': 821}, {'1': 621, '0': 403}, {'1': 634, '0': 390}, {'1': 198, '0': 826}, {'1': 960, '0': 64}]
# [1.0, 0.05078125, 0.8291015625, 0.3916015625, 0.392578125, 0.837890625, 0.0458984375, 1.0, 0.05078125, 0.8017578125, 0.3935546875, 0.380859375, 0.806640625, 0.0625]

# %%
n=8
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

circ.draw(output='mpl')

phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range8 = phi_range
counts8 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

#print(counts8)

# %%
n=10
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

circ.draw(output='mpl')

phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range10 = phi_range
counts10 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

#print(counts10)

# %%
n=12
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

circ.draw(output='mpl')

phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range12 = phi_range
counts12 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

#print(counts12)

# %%
n=14
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

circ.draw(output='mpl')

phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range14 = phi_range
counts14 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

#print(counts12)

# %%
plt.style.use('ggplot')
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(phi_range6,list(map(lambda c: 100/1024*c.get('0',0), counts6)), '.',label='n=6')
ax.plot(phi_range8,list(map(lambda c: 100/1024*c.get('0',0), counts8)), '.',label='n=8')
ax.plot(phi_range10,list(map(lambda c: 100/1024*c.get('0',0), counts10)), '.',label='n=10')
ax.plot(phi_range12,list(map(lambda c: 100/1024*c.get('0',0), counts12)), '.',label='n=12')
ax.plot(phi_range12,list(map(lambda c: 100/1024*c.get('0',0), counts12)), '.',label='n=14')

#ax.plot(phi_range,list(map(lambda c: c.get('1',0), counts)), '.-',label='1')

ax.set_xticks([i*np.pi/2 for i in range(5)])
ax.set_xticklabels(['0', r'$\frac{\pi}{2}$', r'$\pi$',r'$\frac{3\pi}{2}$',r'$2 \pi $'], fontsize=14)
ax.set_xlabel('0')
ax.legend()
plt.show()

# %%
print(list(map(lambda c: 1/1024*c.get('0',0), counts6)))

# %%
print(counts10)
