# %%
# Useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi


from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import BasicAer, execute
from qiskit.quantum_info import Pauli, state_fidelity, basis_state, process_fidelity 

from qiskit.circuit import Parameter


from qiskit import *
IBMQ.load_accounts(hub=None)
from qiskit.tools.monitor import job_monitor, backend_monitor, backend_overview
from qiskit.providers.ibmq import least_busy

from qiskit.compiler import transpile
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor
from qiskit import IBMQ

#provider = IBMQ.load_accounts()

# %%
#Simulation
#Misura di tutti i qubit
n=5
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i])
    


#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
print(circuits[-1].parameters)
circuits[-1].draw(output='mpl')

#circuits[1].draw()


job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range5 = phi_range
counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts5)
print('\n')
print('Counts of 00000')
print(list(map(lambda c: 1/1024*c.get('00000', 0), counts5)))

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 5
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmqx2'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts5)
print('\n')
print('Counts of 00000')
print(list(map(lambda c: 1/1024*c.get('00000', 0), counts5)))

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 5
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts5)
print('\n')
print('Counts of 00000')
print(list(map(lambda c: 1/1024*c.get('00000', 0), counts5)))

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 5
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

device = IBMQ.get_backend('ibmq_16_melbourne')
trans_ghz = transpile(circ, device)
#trans_ghz.draw()

job = execute(trans_ghz,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts5)
print('\n')
print('Counts of 00000')
print(list(map(lambda c: 1/1024*c.get('00000', 0), counts5)))

# %%
trans_ghz.depth()
circ.depth()

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 5
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')

job = execute(circ,
            backend=IBMQ.get_backend('ibmq_qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts5)
print('\n')
print('Counts of 00000')
print(list(map(lambda c: 1/1024*c.get('00000', 0), counts5)))


job_id = job_exp.job_id()
print('JOB ID: {}'.format(job_id))

#retrieved_job = backend.retrieve_job(job_id)
#retrieved_job.result().get_counts(qc)
# Out:
# Phi range
# [0.0, 0.5235987755982988, 1.0471975511965976, 1.5707963267948966, 2.0943951023931953, 2.6179938779914944, 3.141592653589793, 3.665191429188092, 4.1887902047863905, 4.71238898038469, 5.235987755982989, 5.759586531581287]
# Job Status: job is being initialized
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Job Status: job incurred error
# ---------------------------------------------------------------------------
# JobError                                  Traceback (most recent call last)
# <ipython-input-2-ea3a367c1fb4> in <module>
#      44
#      45 phi_range4 = phi_range
# ---> 46 counts5 =[job.result().get_counts(i) for i in range(len(job.result().results))]
#      47
#      48 print('\n')
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in result(self, timeout, wait)
#     225             JobError: if attempted to recover a result on a failed job.
#     226         """
# --> 227         self._wait_for_completion(timeout=timeout, wait=wait)
#     228
#     229         status = self.status()
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in _wait_for_completion(self, timeout, wait)
#     470                 specified timeout.
#     471         """
# --> 472         self._wait_for_submission(timeout)
#     473
#     474         # TODO: reenable during #61.
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in _wait_for_submission(self, timeout)
#     496                 self._status = JobStatus.ERROR
#     497                 self._api_error_msg = str(submit_info['error'])
# --> 498                 raise JobError(str(submit_info['error']))
#     499
#     500     def _wait_for_final_status(self, timeout=None, wait=5):
#
# JobError: "{'status': 400, 'message': 'Generic error', 'code': 'GENERIC_ERROR'}"
