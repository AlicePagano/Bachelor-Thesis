# %%
# Useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import BasicAer, execute
from qiskit.quantum_info import Pauli, state_fidelity, basis_state, process_fidelity 

from qiskit.circuit import Parameter


from qiskit import *
IBMQ.load_accounts(hub=None)
from qiskit.tools.monitor import job_monitor, backend_monitor, backend_overview
from qiskit.providers.ibmq import least_busy

# %%
#Simulation
#Misura solo del qubit 0
n=6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
print(circuits[-1].parameters)
circuits[-1].draw(output='mpl')

#circuits[1].draw()


job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 0')
print(list(map(lambda c: 1/1024*c.get('0',0), counts6)))

# %%
#Simulation
#Misura di tutti i qubit
n=6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(6, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i])
    


#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
print(circuits[-1].parameters)
circuits[-1].draw(output='mpl')

#circuits[1].draw()


job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 000000')
print(list(map(lambda c: 1/1024*c.get('000000', 0), counts6)))

# %%
#Run in real quantum computer
#Misura di solo qubit 0
n = 6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(1, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

#for i in range(n):
#    circ.measure(q[i], c[i])
    
circ.measure(q[0], c[0])  

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 0')
print(list(map(lambda c: 1/1024*c.get('0',0), counts6)))

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(6, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 000000')
print(list(map(lambda c: 1/1024*c.get('000000', 0), counts6)))

# %%
#Simulation GHZ STATE
#Misura di tutti i qubit
n=6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(6, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()


for i in range(n):
    circ.measure(q[i], c[i])
    


#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
print(circuits[-1].parameters)
circuits[-1].draw(output='mpl')

#circuits[1].draw()


job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 000000')
print(list(map(lambda c: 1/1024*c.get('000000', 0), counts6)))
# Out:
# Phi range
# [0.0, 0.4487989505128276, 0.8975979010256552, 1.3463968515384828, 1.7951958020513104, 2.243994752564138, 2.6927937030769655, 3.141592653589793, 3.5903916041026207, 4.039190554615448, 4.487989505128276, 4.936788455641103, 5.385587406153931, 5.8343863566667595]
# set()
#
#
# Counts
# [{'111111': 516, '000000': 508}, {'111111': 493, '000000': 531}, {'111111': 502, '000000': 522}, {'000000': 512, '111111': 512}, {'000000': 517, '111111': 507}, {'111111': 491, '000000': 533}, {'111111': 530, '000000': 494}, {'111111': 544, '000000': 480}, {'000000': 510, '111111': 514}, {'111111': 523, '000000': 501}, {'000000': 529, '111111': 495}, {'111111': 527, '000000': 497}, {'111111': 521, '000000': 503}, {'000000': 517, '111111': 507}]
#
#
# Counts of 000000
# [0.49609375, 0.5185546875, 0.509765625, 0.5, 0.5048828125, 0.5205078125, 0.482421875, 0.46875, 0.498046875, 0.4892578125, 0.5166015625, 0.4853515625, 0.4912109375, 0.5048828125]

# %%
#Run in real quantum computer GHZ State
#Misura di tutti i qubit
n = 6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(6, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()


for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
           
                             for phi_val in phi_range])

job_monitor(job)

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 000000')
print(list(map(lambda c: 1/1024*c.get('000000', 0), counts6)))
# Out:
# Phi range
# [0.0, 0.4487989505128276, 0.8975979010256552, 1.3463968515384828, 1.7951958020513104, 2.243994752564138, 2.6927937030769655, 3.141592653589793, 3.5903916041026207, 4.039190554615448, 4.487989505128276, 4.936788455641103, 5.385587406153931, 5.8343863566667595]
# Job Status: job has successfully run
#
#
# Counts
# [{'101101': 1, '100100': 2, '011110': 12, '001110': 20, '000000': 267, '000111': 21, '100111': 5, '110000': 74, '000110': 9, '010010': 1, '110101': 3, '111010': 11, '100011': 1, '110001': 6, '110100': 2, '011111': 20, '111001': 2, '011010': 1, '000011': 12, '010111': 10, '111000': 14, '111101': 10, '100000': 46, '010000': 48, '010110': 8, '001111': 47, '101111': 24, '101000': 6, '101110': 23, '000101': 4, '110110': 5, '010001': 5, '101011': 3, '000001': 43, '001101': 3, '001010': 2, '100010': 2, '110010': 3, '011100': 5, '100001': 2, '101100': 3, '010101': 3, '011000': 7, '000100': 2, '111111': 82, '011011': 6, '001011': 11, '000010': 6, '011101': 2, '011001': 1, '110011': 4, '110111': 17, '001000': 19, '001100': 2, '111110': 33, '100101': 2, '100110': 5, '111100': 6, '111011': 27, '001001': 3}, {'101101': 3, '100100': 2, '010011': 4, '011110': 4, '001110': 15, '000000': 264, '000111': 32, '100111': 9, '110000': 73, '000110': 11, '010010': 3, '110101': 4, '111010': 12, '100011': 3, '110001': 10, '111001': 4, '011111': 18, '101010': 3, '011010': 1, '000011': 9, '010111': 3, '111000': 16, '111101': 9, '100000': 46, '010000': 67, '010110': 2, '001111': 49, '101111': 22, '101000': 10, '101110': 10, '000101': 2, '110110': 9, '010001': 11, '101011': 5, '000001': 25, '001101': 10, '001010': 4, '110010': 4, '010100': 2, '100001': 6, '101100': 2, '010101': 1, '011000': 4, '000100': 9, '101001': 4, '111111': 82, '011011': 5, '001011': 10, '000010': 4, '011101': 1, '011001': 2, '110011': 4, '110111': 14, '001000': 22, '001100': 5, '111110': 34, '100110': 1, '111100': 4, '111011': 19, '001001': 1}, {'101101': 3, '010011': 1, '011110': 3, '001110': 30, '000000': 277, '000111': 20, '100111': 7, '110000': 79, '000110': 11, '010010': 3, '110101': 4, '111010': 8, '100011': 3, '110001': 13, '110100': 5, '011111': 22, '111001': 4, '101010': 3, '011010': 5, '000011': 6, '010111': 10, '111000': 11, '111101': 11, '100000': 34, '010000': 56, '010110': 1, '001111': 56, '101111': 25, '101000': 5, '101110': 9, '000101': 5, '110110': 9, '010001': 7, '101011': 6, '000001': 28, '001101': 6, '001010': 5, '100010': 1, '110010': 3, '011100': 2, '100001': 3, '101100': 2, '010101': 2, '011000': 11, '000100': 7, '111111': 70, '011011': 3, '001011': 8, '000010': 5, '011101': 6, '011001': 2, '110011': 9, '110111': 16, '001000': 17, '001100': 6, '111110': 35, '100110': 3, '111100': 5, '111011': 15, '001001': 2}, {'101101': 1, '010011': 1, '011110': 11, '001110': 30, '000000': 238, '000111': 18, '100111': 8, '110000': 87, '000110': 9, '110101': 1, '111010': 9, '100011': 5, '110001': 5, '110100': 2, '011111': 21, '111001': 7, '101010': 2, '011010': 1, '000011': 7, '010111': 15, '111000': 17, '111101': 10, '100000': 55, '010000': 61, '010110': 3, '001111': 50, '101111': 27, '101000': 11, '101110': 7, '000101': 3, '110110': 9, '010001': 5, '101011': 11, '000001': 23, '001101': 7, '001010': 9, '100010': 1, '110010': 3, '010100': 2, '100001': 3, '101100': 3, '010101': 2, '011000': 6, '000100': 4, '101001': 3, '111111': 84, '011011': 6, '001011': 10, '000010': 5, '011101': 1, '011001': 3, '110011': 4, '110111': 17, '001000': 15, '001100': 3, '111110': 33, '100101': 2, '100110': 2, '111100': 5, '111011': 18, '001001': 3}, {'101101': 1, '100100': 2, '010011': 4, '011110': 4, '001110': 17, '000000': 248, '000111': 17, '100111': 9, '110000': 72, '000110': 8, '010010': 1, '110101': 1, '111010': 10, '100011': 4, '110001': 9, '111001': 3, '011111': 27, '101010': 3, '011010': 2, '000011': 5, '010111': 4, '111000': 15, '111101': 12, '100000': 64, '010000': 61, '010110': 5, '001111': 57, '101111': 37, '101000': 8, '101110': 7, '000101': 4, '110110': 6, '010001': 10, '101011': 7, '000001': 16, '001101': 7, '001010': 2, '100010': 2, '110010': 2, '011100': 2, '010100': 1, '100001': 5, '101100': 5, '011000': 9, '000100': 3, '101001': 1, '111111': 83, '011011': 3, '001011': 12, '000010': 9, '011101': 4, '011001': 1, '110011': 2, '110111': 10, '001000': 23, '001100': 5, '111110': 36, '1 ...
#
#
# Counts of 000000
# [0.2607421875, 0.2578125, 0.2705078125, 0.232421875, 0.2421875, 0.2392578125, 0.255859375, 0.2490234375, 0.2373046875, 0.2578125, 0.248046875, 0.24609375, 0.2412109375, 0.2587890625]

# %%
#Run in real quantum computer GHZ State
#Misura di tutti i qubit
n = 6
q = QuantumRegister(n, 'q')
c = ClassicalRegister(6, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()


for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
           
                             for phi_val in phi_range])

job_monitor(job)

phi_range6 = phi_range
counts6 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts6)
print('\n')
print('Counts of 000000')
print(list(map(lambda c: 1/1024*c.get('000000', 0), counts6)))
