# %%
# Useful additional packages 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi


from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit import BasicAer, execute
from qiskit.quantum_info import Pauli, state_fidelity, basis_state, process_fidelity 

from qiskit.circuit import Parameter


from qiskit import *
IBMQ.load_accounts(hub=None)
from qiskit.tools.monitor import job_monitor, backend_monitor, backend_overview
from qiskit.providers.ibmq import least_busy

# %%
#Simulation
#Misura di tutti i qubit
n=4
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i])
    


#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
print(circuits[-1].parameters)
circuits[-1].draw(output='mpl')

#circuits[1].draw()


job = execute(circ,
            backend=BasicAer.get_backend('qasm_simulator'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

phi_range4 = phi_range
counts4 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts4)
print('\n')
print('Counts of 0000')
print(list(map(lambda c: 1/1024*c.get('0000', 0), counts4)))
# Out:
# Phi range
# [0.0, 0.6283185307179586, 1.2566370614359172, 1.8849555921538759, 2.5132741228718345, 3.141592653589793, 3.7699111843077517, 4.39822971502571, 5.026548245743669, 5.654866776461628]
# set()
#
#
# Counts
# [{'0000': 1024}, {'0000': 113, '0001': 911}, {'0000': 693, '0001': 331}, {'0000': 672, '0001': 352}, {'0000': 101, '0001': 923}, {'0000': 1024}, {'0000': 90, '0001': 934}, {'0000': 693, '0001': 331}, {'0000': 662, '0001': 362}, {'0000': 95, '0001': 929}]
#
#
# Counts of 0000
# [1.0, 0.1103515625, 0.6767578125, 0.65625, 0.0986328125, 1.0, 0.087890625, 0.6767578125, 0.646484375, 0.0927734375]

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 4
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmq_16_melbourne'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts4 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts4)
print('\n')
print('Counts of 0000')
print(list(map(lambda c: 1/1024*c.get('0000', 0), counts4)))
# Out:
# Phi range
# [0.0, 0.6283185307179586, 1.2566370614359172, 1.8849555921538759, 2.5132741228718345, 3.141592653589793, 3.7699111843077517, 4.39822971502571, 5.026548245743669, 5.654866776461628]
# Job Status: job is being initialized
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Got a 400 code response to /api/Jobs: {"error":{"status":400,"message":"Generic error","code":"GENERIC_ERROR"}}
# Job Status: job incurred error
# ---------------------------------------------------------------------------
# JobError                                  Traceback (most recent call last)
# <ipython-input-3-57620fb3463d> in <module>
#      45
#      46 phi_range4 = phi_range
# ---> 47 counts4 =[job.result().get_counts(i) for i in range(len(job.result().results))]
#      48
#      49 print('\n')
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in result(self, timeout, wait)
#     225             JobError: if attempted to recover a result on a failed job.
#     226         """
# --> 227         self._wait_for_completion(timeout=timeout, wait=wait)
#     228
#     229         status = self.status()
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in _wait_for_completion(self, timeout, wait)
#     470                 specified timeout.
#     471         """
# --> 472         self._wait_for_submission(timeout)
#     473
#     474         # TODO: reenable during #61.
#
# ~/anaconda3/envs/Qiskitenv/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqjob.py in _wait_for_submission(self, timeout)
#     496                 self._status = JobStatus.ERROR
#     497                 self._api_error_msg = str(submit_info['error'])
# --> 498                 raise JobError(str(submit_info['error']))
#     499
#     500     def _wait_for_final_status(self, timeout=None, wait=5):
#
# JobError: "{'status': 400, 'message': 'Generic error', 'code': 'GENERIC_ERROR'}"

# %%
#Run in real quantum computer
#Misura di tutti i qubit
n = 4
q = QuantumRegister(n, 'q')
c = ClassicalRegister(n, 'c') #n

circ = QuantumCircuit(q,c)
phi = Parameter('phi')

circ.h(q[0])

for i in range(n-1):
    circ.cx(i, i+1)
    
circ.barrier()
circ.rz(phi, range(n))
circ.barrier()

for i in reversed(range(n-1)):
    circ.cx(i, i+1)

circ.h(q[0])

circ.barrier()

for i in range(n):
    circ.measure(q[i], c[i]) 

#circ.draw(output='mpl')

print('Phi range')
phi_range = [np.pi*j/(n+1) for j in range(2*n+1+1)]
print(phi_range)
circuits = [circ.bind_parameters({phi: phi_val}) for phi_val in phi_range] 
#print(circuits[3].parameters)
#circuits[11].draw(output='mpl')


job = execute(circ,
            backend=IBMQ.get_backend('ibmqx4'),
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

job_monitor(job)

phi_range4 = phi_range
counts4 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts4)
print('\n')
print('Counts of 0000')
print(list(map(lambda c: 1/1024*c.get('0000', 0), counts4)))

# %%
# Qiskit Aer noise module imports
from qiskit.providers.aer.noise import NoiseModel
from qiskit.providers.aer.noise.errors import QuantumError, ReadoutError
from qiskit.providers.aer.noise.errors import pauli_error
from qiskit.providers.aer.noise.errors import depolarizing_error
from qiskit.providers.aer.noise.errors import thermal_relaxation_error

#NOISE MODEL
# Example error probabilities
p_reset = 0.03
p_meas = 0.1
p_gate1 = 0.05

# QuantumError objects
error_reset = pauli_error([('X', p_reset), ('I', 1 - p_reset)])
error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
error_gate1 = pauli_error([('X',p_gate1), ('I', 1 - p_gate1)])
error_gate2 = error_gate1.tensor(error_gate1)

# Add errors to noise model
noise_bit_flip = NoiseModel()
noise_bit_flip.add_all_qubit_quantum_error(error_reset, "reset")
noise_bit_flip.add_all_qubit_quantum_error(error_meas, "measure")
noise_bit_flip.add_all_qubit_quantum_error(error_gate1, ["u1", "u2", "u3"])
noise_bit_flip.add_all_qubit_quantum_error(error_gate2, ["cx"])

print(noise_bit_flip)

# %%
# Run the noisy simulation
#job = execute(circ, simulator,
 #             basis_gates=noise_bit_flip.basis_gates,
 #             noise_model=noise_bit_flip)
#result_bit_flip = job.result()
#counts_bit_flip = result_bit_flip.get_counts(0)

# Plot noisy output
#plot_histogram(counts_bit_flip)


# Simulator
simulator = QasmSimulator()

job = execute(circ,simulator,
              basis_gates=noise_bit_flip.basis_gates,
              noise_model=noise_bit_flip,
            parameter_binds=[{phi: phi_val}
              for phi_val in phi_range])

counts4 =[job.result().get_counts(i) for i in range(len(job.result().results))] 

print('\n')
print('Counts')
print(counts4)
print('\n')
print('Counts of 0000')
print(list(map(lambda c: 1/1024*c.get('0000', 0), counts4)))
